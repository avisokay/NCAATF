# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
from sklearn import preprocessing
import datetime

import pylab as pl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %matplotlib inline

# %%
def convert_seconds(secs):
    '''Takes a total number of seconds and returns in %M:%S.%f format'''
    date = datetime.datetime.utcfromtimestamp(secs)
    output = datetime.datetime.strftime(date, "%M:%S.%f")
    return output

# %%
# handle a bit differently because men run 110H while women run 100H
men_running_events = ['100', '200', '400', '800', '1500', '5000', '10000',
       '110H', '400H', '3000S', '4x100', '4x400']
women_running_events = ['100', '200', '400', '800', '1500', '5000', '10000', '100H',
       '400H', '3000S', '4x100', '4x400']

# %%
df100 = pd.read_csv('tfrrs_scraped.csv')

# %% [markdown]
# ### Separate 2021 from 2010-2019

# %%
df100_2021 = df100[df100['CHAMP_YEAR'] == 2021]

# %%
df100_not2021 = df100[df100['CHAMP_YEAR'] != 2021]

# %%
# summary stats for TIME_SECS running events
description = df100.groupby(['DIVISION', 'CHAMP_YEAR', 'EVENT', 'SEX'])['TIME_SECS'].describe(percentiles = [.2, .4, .6, .8])
description.sort_values(['DIVISION', 'CHAMP_YEAR', 'EVENT', 'SEX'], ascending=[True, False, True, True], inplace=True)

# %%
description
# Out:
#                                  count       mean        std      min  \
# DIVISION CHAMP_YEAR EVENT SEX
# D1       2021       100   Men    100.0    10.3007   0.103546     9.94
#                           Women  100.0    11.4057   0.153223    10.96
#                     10000 Men    100.0  1739.4049  25.564443  1667.27
#                           Women  100.0  2059.3049  46.118777  1944.38
#                     100H  Women  100.0    13.2914   0.255632    12.53
#                     110H  Men    100.0    13.8758   0.213887    13.22
#                     1500  Men    100.0   221.2116   2.072349   216.00
#                           Women  100.0   256.5664   2.662343   248.38
#                     200   Men    100.0    20.7105   0.245975    19.81
#                           Women  100.0    23.2933   0.289252    22.30
#                     3000S Men    100.0   531.4380   6.287706   512.92
#                           Women  100.0   612.3718  13.642009   571.37
#                     400   Men    100.0    46.2260   0.661985    44.30
#                           Women  100.0    53.1125   0.909768    51.14
#                     400H  Men    100.0    51.3825   0.806850    49.12
#                           Women  100.0    59.0000   1.149940    55.59
#                     4x100 Men    100.0    39.8749   0.482048    38.49
#                           Women  100.0    44.6477   0.673585    42.63
#                     4x400 Men    100.0   187.7037   2.501186   180.23
#                           Women  100.0   216.2746   3.730243   206.63
#                     5000  Men    100.0   822.8862   9.243898   799.98
#                           Women  100.0   956.6461  14.081713   917.79
#                     800   Men    100.0   108.7769   1.001635   105.80
#                           Women  100.0   125.4109   1.770575   117.73
#                     DT    Men      0.0        NaN        NaN      NaN
#                           Women    0.0        NaN        NaN      NaN
#                     Dec   Men      0.0        NaN        NaN      NaN
#                     HJ    Men      0.0        NaN        NaN      NaN
#                           Women    0.0        NaN        NaN      NaN
#                     HT    Men      0.0        NaN        NaN      NaN
# ...                                ...        ...        ...      ...
# D3       2010       400   Men    100.0    48.8532   0.550984    47.13
#                           Women  100.0    57.7692   0.991631    55.06
#                     400H  Men    100.0    54.6866   1.108237    50.66
#                           Women  100.0    64.5991   1.318021    60.51
#                     4x100 Men    100.0    42.4162   0.594423    40.84
#                           Women  100.0    49.3292   0.944369    46.59
#                     4x400 Men    100.0   199.7607   3.452275   191.18
#                           Women  100.0   240.1483   5.418386   223.54
#                     5000  Men    100.0   889.3570  11.697712   857.10
#                           Women  100.0  1059.0580  22.740625  1001.16
#                     800   Men    100.0   113.4118   1.313878   108.69
#                           Women  100.0   134.7257   2.386486   129.08
#                     DT    Men      0.0        NaN        NaN      NaN
#                           Women    0.0        NaN        NaN      NaN
#                     Dec   Men      0.0        NaN        NaN      NaN
#                     HJ    Men      0.0        NaN        NaN      NaN
#                           Women    0.0        NaN        NaN      NaN
#                     HT    Men      0.0        NaN        NaN      NaN
#                           Women    0.0        NaN        NaN      NaN
#                     Hep   Women    0.0        NaN        NaN      NaN
#                     JT    Men      0.0        NaN        NaN      NaN
#                           Women    0.0        NaN        NaN      NaN
#                     LJ    Men      0.0        NaN        NaN      NaN
#                           Women    0.0        NaN        NaN      NaN
#                     PV    Men      0.0        NaN        NaN      NaN
#                           Women    0.0        NaN        NaN      NaN
#                     SP    Men      0.0        NaN        NaN      NaN
#                           Women    0.0        NaN        NaN      NaN
#                     TJ    Men      0.0        NaN        NaN      NaN
#                           Women    0.0        NaN        NaN      NaN
#
#                                       20%       40%       50%       60%  \
# DIVISION CHAMP_YEAR EVENT SEX
# D1       2021       100   Men      10.230    10.290    10.325    10.340
#                           Women    11.280    11.376    11.410    11.494
#                     10000 Men    1719.878  1735.724  1744.370  1748.282
#                           Women  2024.220  2048.108  2067.795  2082.240
#                     100H  Women    13.116    13.266    13.310    13.408
#                     110H  Men      13.690    13.890    13.940    13.980
#                     1500  Men     219.014   221.126   222.090   222.436
#                           Women   254.322   256.234   256.810   257.734
#                     200   Men      20.518    20.710    20.785    20.830
#                           Women    23.028    23.230    23.355    23.430
#                     3000S Men     526.088   530.048   531.860   534.322
#                           Women   600.372   609.978   614.140   617.488
#                     400   Men      45.776    46.294    46.475    46.580
#                           Women    52.278    53.012    53.275    53.402
#                     400H  Men      50.782    51.246    51.480    51.760
#                           Women    57.918    58.758    59.090    59.610
#                     4x100 Men      39.556    39.846    39.985    40.100
#                           Women    44.052    44.542    44.765    44.964
#                     4x400 Men     185.718   187.510   188.195   188.922
#                           Women   213.232   216.266   217.265   218.184
#                     5000  Men     815.176   823.624   825.690   827.130
#                           Women   942.260   954.198   959.050   962.586
#                     800   Men     107.918   108.794   109.020   109.234
#                           Women   124.394   125.460   126.000   126.374
#                     DT    Men         NaN       NaN       NaN       NaN
#                           Women       NaN       NaN       NaN       NaN
#                     Dec   Men         NaN       NaN       NaN       NaN
#                     HJ    Men         NaN       NaN       NaN       NaN
#                           Women       NaN       NaN       NaN       NaN
#                     HT    Men         NaN       NaN       NaN       NaN
# ...                                   ...       ...       ...       ...
# D3       2010       400   Men      48.320    48.782    48.980    49.178
#                           Women    56.838    57.610    57.990    58.274
#                     400H  Men      53.800    54.668    54.905    55.254
#                           Women    63.220    64.348    64.930    65.306
#                     4x100 Men      41.912    42.340    42.495    42.668
#                           Women    48.438    49.260    49.520    49.710
#                     4x400 Men     195.654   199.762   200.345   201.410
#                           Women   234.994   240.292   241.665   242.448
#                     5000  Men     879.808   887.672   890.455   894.196
#                           Women  1040.838  1053.666  1062.990  1069.090
#                     800   Men     112.354   113.262   113.545   114.024
#                           Women   132.752   134.060   134.900   135.854
#                     DT    Men         NaN       NaN       NaN       NaN
#                           Women       NaN       NaN       NaN       NaN
#                     Dec   Men         NaN       NaN       NaN       NaN
#                     HJ    Men         NaN       NaN       NaN       NaN
#                           Women       NaN       NaN       NaN       NaN
#                     HT    Men         NaN       NaN       NaN       NaN
#                           Women       NaN       NaN       NaN       NaN
#                     Hep   Women       NaN       NaN       NaN       NaN
#                     JT    Men         NaN       NaN       NaN       NaN
#                           Women       NaN       NaN       NaN       NaN
#                     LJ    Men         NaN       NaN       NaN       NaN
#                           Women       NaN       NaN       NaN       NaN
#                     PV    Men         NaN       NaN       NaN       NaN
#                           Women       NaN       NaN       NaN       NaN
#                     SP    Men         NaN       NaN       NaN       NaN
#                           Women       NaN       NaN       NaN       NaN
#                     TJ    Men         NaN       NaN       NaN       NaN
#                           Women       NaN       NaN       NaN       NaN
#
#                                       80%      max
# DIVISION CHAMP_YEAR EVENT SEX
# D1       2021       100   Men      10.390    10.44
#                           Women    11.552    11.61
#                     10000 Men    1759.190  1776.67
#                           Women  2099.738  2127.53
#                     100H  Women    13.542    13.62
#                     110H  Men      14.060    14.14
#                     1500  Men     223.102   223.63
#                           Women   259.144   260.14
#                     200   Men      20.912    21.00
#                           Women    23.560    23.67
#                     3000S Men     537.388   540.82
#                           Women   625.612   631.68
#                     400   Men      46.766    46.95
#                           Women    54.066    54.35
#                     400H  Men      52.122    52.51
#                           Women    60.104    60.50
#                     4x100 Men      40.302    40.48
#                           Women    45.280    45.51
#                     4x400 Men     190.062   190.81
#                           Women   219.514   220.84
#                     5000  Men     831.250   833.45
#                           Women   970.428   976.40
#                     800   Men     109.740   109.97
#                           Women   126.842   126.99
#                     DT    Men         NaN      NaN
#                           Women       NaN      NaN
#                     Dec   Men         NaN      NaN
#                     HJ    Men         NaN      NaN
#                           Women       NaN      NaN
#                     HT    Men         NaN      NaN
# ...                                   ...      ...
# D3       2010       400   Men      49.380    49.53
#                           Women    58.676    59.05
#                     400H  Men      55.650    55.99
#                           Women    65.882    66.40
#                     4x100 Men      42.982    43.27
#                           Women    50.178    50.61
#                     4x400 Men     202.928   204.69
#                           Women   244.772   247.57
#                     5000  Men     900.050   906.03
#                           Women  1080.688  1090.22
#                     800   Men     114.682   115.16
#                           Women   137.032   138.35
#                     DT    Men         NaN      NaN
#                           Women       NaN      NaN
#                     Dec   Men         NaN      NaN
#                     HJ    Men         NaN      NaN
#                           Women       NaN      NaN
#                     HT    Men         NaN      NaN
#                           Women       NaN      NaN
#                     Hep   Women       NaN      NaN
#                     JT    Men         NaN      NaN
#                           Women       NaN      NaN
#                     LJ    Men         NaN      NaN
#                           Women       NaN      NaN
#                     PV    Men         NaN      NaN
#                           Women       NaN      NaN
#                     SP    Men         NaN      NaN
#                           Women       NaN      NaN
#                     TJ    Men         NaN      NaN
#                           Women       NaN      NaN
#
# [1386 rows x 10 columns]

# %% [markdown]
# # Visualizations

# %%
# queried list of dfs, one for each year

def query_each_year(df, division, sex, event):
    '''Takes df, returns list of dfs for each year with given parameters.'''
    
    results = []
    for year in df.CHAMP_YEAR.unique():
        new_df = df[(df['CHAMP_YEAR'] == year) & (df['DIVISION'] == division) & (df['SEX'] == sex) & (df['EVENT'] == event)]
        results.append(new_df)
    return results

# %%
# use queried list of dfs for each year to create a histogram for each year

def histograms_each_year(df, division, sex, event):
    '''Creates a histogram for each df in df_list after query constraints'''
    
    df_list = query_each_year(df, division, sex, event)
    
    for df in df_list:
        fig, ax = plt.subplots()
        plot = df.TIME_SECS.plot(kind='hist', bins=15, ax=ax)
        plot = plot.set_xticklabels(df['TIME'], rotation=20)
        plt.gcf().set_size_inches(8,5)
        pl.suptitle(str(df.CHAMP_YEAR.iloc[0]) + ' ' + df.SEX.iloc[0] + '\'s ' + df.EVENT.iloc[0])

# %% [markdown]
# ### Example: lets make histograms for D1 men's 1500

# %%
histograms_each_year(df100, 'D1', 'Men', '1500')

# %%
def hist_density_overlap(df, division, sex, event):
    '''Creates an overlapping histogram and density for each df in queried list of dfs for each year'''
    
    df_list = query_each_year(df, division, sex, event)
    
    for df in df_list:
        plot = sns.distplot(df.TIME_SECS, kde=True, bins=15, hist=True, label=df.CHAMP_YEAR.iloc[0])
        plot = plot.set_xticklabels(df['TIME'], rotation=20)
        plt.legend()
        plt.gcf().set_size_inches(20,12)
        pl.suptitle(division + ' ' + sex + '\'s ' + event)

# %%
hist_density_overlap(df100, 'D1', 'Men', '1500')

# %% [markdown]
# ### Take a look at combined distribution across all years for each event division and sex

# %%
# queried df, all years, for specified division sex event and 

def query_all_years(df, division, sex, event):
    '''Takes df, returns list of dfs for each year with given parameters.'''
    
    results = df[(df['CHAMP_YEAR'] != 2021) & (df['DIVISION'] == division) & (df['SEX'] == sex) & (df['EVENT'] == event)]
    return results

# %%
# histogram for results for given division, sex, event and all years

def histogram_all_years(df, division, sex, event):
    '''Takes a queried dataframe and combines all TIME_SECS for that given division sex and event across all years'''
    
    df_graph = query_all_years(df, division, sex, event)
    
    fig, ax = plt.subplots()
    plot = df_graph.TIME_SECS.plot(kind='hist', bins=15, grid=True, ax=ax)
    plot = plot.set_xticklabels(df_graph['TIME'], rotation=20)
    pl.suptitle(str(df_graph.DIVISION.iloc[0] + ' ' + df_graph.SEX.iloc[0] + '\'s ' + df_graph.EVENT.iloc[0]))

# %%
histogram_all_years(df100, 'D1', 'Men', '1500')

# %% [markdown]
# ### Function that creates a dataframe with
# ### min, average, median, max, std, and quintiles for TIME_SECS for each event across ALL years, division, sex, event

# %%
def events_desc(df, division, sex):
    '''Returns a dataframe with summary stats for TIME_SECS for each event for all years given division and sex'''
    series_list = []
    for event in df.EVENT.unique():
        df_desc = df[(df['DIVISION'] == division) & (df100['SEX'] == sex) & (df100['EVENT'] == event)].TIME_SECS.describe(percentiles=[0.2, 0.4, 0.6, 0.8])
        series_list.append(df_desc)
    result = pd.DataFrame(series_list, index=df100.EVENT.unique())
    return result

# %%
D2women_desc = events_desc(df100, 'D3', 'Women')
D2women_desc.head()
# Out:
#        count        mean       std     min      20%      40%      50%  \
# 100   1100.0   12.291618  0.197822   11.41   12.130   12.270   12.330
# 200   1100.0   25.233245  0.419045   23.29   24.870   25.196   25.315
# 400   1100.0   57.512009  1.031197   53.18   56.618   57.420   57.680
# 800   1100.0  134.664218  2.601018  122.34  132.396  134.456  135.240
# 1500  1100.0  278.481236  5.298277  255.77  273.908  277.726  279.165
#
#           60%      80%     max
# 100    12.370   12.450   12.70
# 200    25.410   25.560   26.04
# 400    57.960   58.400   59.59
# 800   135.830  136.820  140.47
# 1500  280.544  283.074  290.32

# %% [markdown]
# ### Lets look at descriptive statistics for TIME_SECS and do some statistical hypothesis testing.

# %%
event_means = df100.groupby(['CHAMP_YEAR', 'DIVISION', 'SEX', 'EVENT']).TIME_SECS.mean()
event_means.head()
# Out:
# CHAMP_YEAR  DIVISION  SEX  EVENT
# 2010        D1        Men  100        10.3757
#                            10000    1758.4778
#                            110H       13.9928
#                            1500      223.6396
#                            200        20.8692
# Name: TIME_SECS, dtype: float64

# %%
# mean for event in 2021
def mean_event_2021(division, sex, event):
    '''Returns the averagze TIME_SECS for given division sex and event in year 2021'''
    return df100_2021[(df100_2021['DIVISION'] == division) & (df100_2021['SEX'] == sex) & (df100_2021['EVENT'] == event)].TIME_SECS.mean()

# %%
def event_desc_each_year(df, division, sex, event):
    '''Returns a dataframe of summary stats of TIME_SECS for each year for given division, sex and event.  
    Plots a regplot with 95% confidence interval for 2010-2019 mean observations in blue and the 2021 mean observation in red.'''
    
    series_list = []
    for year in df.CHAMP_YEAR.unique():
        df_desc = df[(df['CHAMP_YEAR'] == year) & (df['DIVISION'] == division) & (df['SEX'] == sex) & (df['EVENT'] == event)].TIME_SECS.describe(percentiles=[0.2, 0.4, 0.6, 0.8])        
        series_list.append(df_desc)
        
    result = pd.DataFrame(series_list, index=df.CHAMP_YEAR.unique())
    result['CONVERT'] = [convert_seconds(x) for x in result['mean']]
    
    # plot
    fig, ax = plt.subplots()
    plot = sns.regplot(data = result.reset_index(), x = 'index', y = 'mean', ci=95).set_title(division + ' ' + sex + '\'s ' + event)
    plot.yticks=result['CONVERT']
    
    plt.gcf().set_size_inches(10,6)
    
    # add 2021 mean datapoint to plot as a red dot
    plt.scatter(x=2021, y=mean_event_2021(division, sex, event), color='r')
    return result

# %%
df_descD1men1500 = event_desc_each_year(df100_not2021, 'D1', 'Men', '100')

# %% [markdown]
# ### Take a look at every event for a given division and sex.

# %%
def regplots(division, sex):
    '''Create a regplot for 2019 mean times in blue and 2021 mean in red for given division and sex'''
    for event in df100.EVENT.unique():
        if sex == 'Men':
            if event in men_running_events:
                event_desc_each_year(df100_not2021, division, sex, event)
        else: 
            if event in women_running_events:
                event_desc_each_year(df100_not2021, division, sex, event)

# %%
results = regplots('D1', 'Men')

# %% [markdown]
# ### Normalize TIME_SECS for each year, sex division and event so that distributions can be compared

# %%
group = df100.groupby(['CHAMP_YEAR', 'SEX', 'DIVISION', 'EVENT']).TIME_SECS

# divide each time in time_secs by the mean for it's group
df100['NORM_TIME-year'] = df100['TIME_SECS'] / group.transform('mean')

# %%
group = df100.groupby(['SEX', 'DIVISION', 'EVENT']).TIME_SECS

# divide each time in time_secs by the mean for it's group
df100['NORM_TIME'] = df100['TIME_SECS'] / group.transform('mean')

# %%
df100.describe()
# Out:
#             POSITION     CHAMP_YEAR     TIME_SECS       POINTS     NORM_TIME  \
# count  138589.000000  138589.000000  79200.000000  6589.000000  79200.000000
# mean       49.944851    2015.090440    360.502504  5444.935954      1.000000
# std        28.644186       3.315104    567.337925  1129.766195      0.018907
# min         1.000000    2010.000000      9.870000  1353.000000      0.868976
# 25%        25.000000    2012.000000     35.227500  4485.000000      0.989542
# 50%        50.000000    2015.000000     85.965000  5382.000000      1.003007
# 75%        75.000000    2018.000000    343.722500  6324.000000      1.012199
# max       100.000000    2021.000000   2428.110000  8539.000000      1.080964
#
#        NORM_TIME-year
# count    79200.000000
# mean         1.000000
# std          0.017971
# min          0.870631
# 25%          0.990224
# 50%          1.003516
# 75%          1.012157
# max          1.062488

# %%
# histogram for results for given division, sex, event and all years

def histogram_all_years_NORM(df, division, sex, event):
    '''Takes a queried dataframe and combines all NORM_TIME for that given division sex and event across all years'''
    
    df_graph = query_all_years(df, division, sex, event)
    
    fig, ax = plt.subplots()
    plot = df_graph.NORM_TIME.plot(kind='hist', bins=15, grid=True, ax=ax)
    plt.xlabel('TIME_SECS / MEAN')
    pl.suptitle(str(df_graph.DIVISION.iloc[0] + ' ' + df_graph.SEX.iloc[0] + '\'s ' + df_graph.EVENT.iloc[0]))

# %%
histogram_all_years_NORM(df100, 'D1', 'Men', '1500')

# %%
df100_2021.head()
# Out:
#    POSITION  CHAMP_YEAR DIVISION EVENT  SEX           ATHLETE  YEAR  \
# 0         1        2021       D1   100  Men  Martin, JoVaughn  SO-2
# 1         2        2021       D1   100  Men     Amoah, Joseph  SR-4
# 2         3        2021       D1   100  Men   Williams, Micah  FR-1
# 3         4        2021       D1   100  Men   Laird, Terrance  JR-3
# 4         5        2021       D1   100  Men   Jewell, Zachary  SR-4
#
#                TEAM   TIME  TIME_SECS MARK CONV  POINTS  \
# 0     Florida State   9:94       9.94  NaN  NaN     NaN
# 1      Coppin State  10:00      10.00  NaN  NaN     NaN
# 2            Oregon  10:03      10.03  NaN  NaN     NaN
# 3               LSU  10:06      10.06  NaN  NaN     NaN
# 4  Central Arkansas  10:07      10.07  NaN  NaN     NaN
#
#                              MEET     MEET DATE  NORM_TIME  NORM_TIME-year
# 0       UF Tom Jones Invitational  Apr 16, 2021   0.964832        0.964983
# 1         2021 Aggie Invitational  Apr 10, 2021   0.970656        0.970808
# 2        2021 Desert Heat Classic   May 1, 2021   0.973568        0.973720
# 3  LSU Boots Garland Invitational  Apr 17, 2021   0.976480        0.976633
# 4     John McDonnell Invitational  Apr 23, 2021   0.977451        0.977603

# %%
for year in df100_not2021.CHAMP_YEAR.unique():
    print(year)
# Out:
# 2019
# 2018
# 2017
# 2016
# 2015
# 2014
# 2013
# 2012
# 2011
# 2010

# %%
plot = plt.scatter(df100_not2021.CHAMP_YEAR, df100_not2021.NORM_TIME, color='b')
plot = plt.scatter(x=df100_2021.CHAMP_YEAR, y=df100_2021.NORM_TIME, color='r')
