# %%
import pandas as pd
import numpy as np
import re
import datetime
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup

# %% [markdown]
# ### Intermediate functions I will use to clean the data

# %%
def add_events(df_list):
    '''Event list (alternating sexes for each event).'''
    events = ['100', '100', '200', '200', '400', '400', '800', '800', '1500', '1500', '5000', '5000', '10000', '10000', 
              '100H', '100H', '400H', '400H', '3000S', '3000S', '4x100', '4x100', '4x400', '4x400', 
              'HJ', 'HJ', 'PV', 'PV', 'LJ', 'LJ', 'TJ', 'TJ', 'SP', 'SP', 'DT', 'DT', 'HT', 'HT', 'JT', 'JT', 
              'Dec', 'Hep']
    for i in range(len(df_list)):
        df_list[i]['EVENT'] = events[i]

# %%
def add_sex(df_list):
    # male recorded first in df for each event except last two dfs (hep and dec are reversed for some reason)
    for i in range(len(df_list)-2):
        if i%2 == 0:
            df_list[i]['SEX'] = 'Male'
        else:
            df_list[i]['SEX'] = 'Female'
    df_list[40]['SEX'] = 'Female'
    df_list[41]['SEX'] = 'Male'

# %%
def add_division(df_list, division):
    '''division from function argument''' 
    for i in range(len(df_list)):
        df_list[i]['DIVISION'] = division

# %%
def add_champ_year(df_list):
    '''last 4 chars from meet date string as champ year'''
    for i in range(len(df_list)):
        df_list[i]['CHAMP_YEAR'] = [j[-4:] for j in df_list[i]['MEET DATE']]

# %%
def clean_time(df_list):
    '''Takes time in format %M:%S.%f or %S.%f and converts to %M:%S.%f or %S.%f and then creates 
    new variable for total seconds.'''
    
    for df in df_list:
        if ~df['TIME'].astype(str).str.contains('nan').any():
            df['TIME'] = df['TIME'].astype(str) # make sure all times are str format
            df['TIME'] = [re.sub(re.compile(r'\([^)]*\)'), '', i) for i in df['TIME']]
            df['TIME'] = df['TIME'].str.replace('.',':').str.replace('@','').str.replace('h','')

# %%
def add_total_seconds(df_list):
    '''Takes dfs from df_list that have had TIME cleaned and creates a TIME_SECS column of total seconds'''
    for df in df_list:
        if ~df['TIME'].astype(str).str.contains('nan').any():
            results = []
            for time in df['TIME']:
                if len(time) <6:
                    date_time = datetime.datetime.strptime(time, '%S:%f')
                    a_timedelta = date_time - datetime.datetime(1900, 1, 1)
                    results.append(a_timedelta.total_seconds())
                else:
                    date_time = datetime.datetime.strptime(time, "%M:%S:%f")
                    a_timedelta = date_time - datetime.datetime(1900, 1, 1)
                    results.append(a_timedelta.total_seconds())
            df['TIME_SECS'] = results

# %% [markdown]
# ### Combine functions into one cleaning function

# %%
def clean_dfs(df_list, division):
    '''Take in list of dataframes, and division(str).
       Loop through each df in df_list and add column for:
       event, sex, division and championship year.
       Reorder rename and drop columns appropriately.
       Add TIME_SECS from TIME column for running events.
       '''
    
    add_events(df_list)
    add_sex(df_list)
    add_division(df_list, division)
    add_champ_year(df_list)
    
    # rename column to POSITION
    for i in range(len(df_list)):
        df_list[i].rename(columns={'Unnamed: 0' : 'POSITION'}, inplace=True)
    
    # reorder and drop columns
    col_names = ['POSITION', 'CHAMP_YEAR', 'DIVISION', 'EVENT', 'SEX', 'ATHLETE', 'YEAR', 'TEAM', 'TIME', 'TIME_SECS', 
                 'MARK', 'CONV', 'POINTS', 'MEET', 'MEET DATE']    
    for i in range(len(df_list)):
        df_list[i] = df_list[i].reindex(columns=col_names)
        
    
    clean_time(df_list)
    add_total_seconds(df_list)

# %% [markdown]
# ### Final function that loops through list of urls, scrapes and then cleans them.

# %%
def scrape_tfrrs(url_list, division):
    '''For each url in the list, clean the dfs and return a concatenated version of all dfs'''
    cleaned_dfs = []
    for url in url_list:
        # scrape url into list of dfs
        req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
        webpage = urlopen(req).read()
        soup = BeautifulSoup(webpage)
        df_list = pd.read_html(webpage)
        
        # clean each df in df_list
        clean_dfs(df_list, 'D1')
        
        # add each cleaned df to cleaned_dfs list
        for i in df_list:
            cleaned_dfs.append(i)
        
    # concatenate cleaned_dfs list into one long dataframe
    result = pd.concat(cleaned_dfs)
    result.index = range(len(result))
    
    return result

# %% [markdown]
# ### TEST

# %%
d1_urls = ['https://www.tfrrs.org/archived_lists/2568/2019_NCAA_Division_I_Outdoor_Qualifying_(FINAL)/2019/o', 
           'https://www.tfrrs.org/archived_lists/2279/2018_NCAA_Division_I_Outdoor_Qualifying_(FINAL)/2018/o']

# %%
# %%time 
d1_scraped = scrape_tfrrs(d1_urls, 'D1')
# Out:
# Wall time: 2min 21s

# %%
d1_scraped.index = range(len(d1_scraped))

# %%
d1_scraped.head()
# Out:
#    POSITION CHAMP_YEAR DIVISION EVENT  SEX            ATHLETE  YEAR  \
# 0         1       2019       D1   100  Men    Oduduru, Divine  JR-3
# 1         2       2019       D1   100  Men       Burke, Mario  SR-4
# 2         3       2019       D1   100  Men  Gillespie, Cravon  SR-4
# 3         4       2019       D1   100  Men  Sani Brown, Hakim  SO-2
# 4         5       2019       D1   100  Men    Ekevwo, Raymond  JR-3
#
#          TEAM   TIME  TIME_SECS MARK CONV  POINTS  \
# 0  Texas Tech   9:94       9.94  NaN  NaN     NaN
# 1     Houston   9:95       9.95  NaN  NaN     NaN
# 2      Oregon   9:97       9.97  NaN  NaN     NaN
# 3     Florida   9:99       9.99  NaN  NaN     NaN
# 4     Florida  10:02      10.02  NaN  NaN     NaN
#
#                                                MEET     MEET DATE
# 0                      Michael Johnson Invitational  Apr 19, 2019
# 1  The American Outdoor Track & Field Championships  May 10, 2019
# 2           2019 Pac-12 Track & Field Championships   May 4, 2019
# 3           SEC Outdoor Track & Field Championships   May 9, 2019
# 4           SEC Outdoor Track & Field Championships   May 9, 2019

# %% [markdown]
# ### 1 URL AT A TIME

# %%
# %%time
# start with 2019 Outdoor D1
d1_top100 = 'https://www.tfrrs.org/archived_lists/2568/2019_NCAA_Division_I_Outdoor_Qualifying_(FINAL)/2019/o'
d1_top500 = 'https://www.tfrrs.org/lists/2568.html?limit=%3C%3D500&event_type=all&year=&gender=x'
d12017 = 'https://www.tfrrs.org/archived_lists/1912/2017_NCAA_Div._I_Outdoor_Qualifying_(FINAL)/2017/o'

req = Request(d12017, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BeautifulSoup(webpage)
dfs = pd.read_html(webpage)
# Out:
# Wall time: 1min 11s

# %%
# create deep copy of dfs to work with
dfs_copy = [i.copy(deep=True) for i in dfs]

# %%
dfs_copy[41]
# Out:
#     POSITION CHAMP_YEAR DIVISION EVENT   SEX                  ATHLETE  YEAR  \
# 0          1       2017       D1   Dec  Male           Victor, Lindon  SR-4
# 1          2       2017       D1   Dec  Male          Williams, Devon  SR-4
# 2          3       2017       D1   Dec  Male            Wieland, Luca  SR-4
# 3          4       2017       D1   Dec  Male           Duckworth, Tim  JR-3
# 4          5       2017       D1   Dec  Male             Saluri, Karl  JR-3
# 5          6       2017       D1   Dec  Male             Walton, Cody  JR-3
# 6          7       2017       D1   Dec  Male             Filip, Scott  JR-3
# 7          8       2017       D1   Dec  Male             Mahler, Wolf  SR-4
# 8          9       2017       D1   Dec  Male            Price, Hunter  JR-3
# 9         10       2017       D1   Dec  Male           Leemet, Markus  JR-3
# 10        11       2017       D1   Dec  Male            Wasik, Steele  JR-3
# 11        12       2017       D1   Dec  Male          Bastien, Steven  SR-4
# 12        13       2017       D1   Dec  Male               Lawson, TJ  FR-1
# 13        14       2017       D1   Dec  Male           Jacobus, Derek  JR-3
# 14        15       2017       D1   Dec  Male            Veith, Hunter  JR-3
# 15        16       2017       D1   Dec  Male             Delgado, Joe  JR-3
# 16        17       2017       D1   Dec  Male              Moore, Gabe  SO-2
# 17        18       2017       D1   Dec  Male             Modin, Mitch  SR-4
# 18        19       2017       D1   Dec  Male            Ehrhardt, Tim  JR-3
# 19        20       2017       D1   Dec  Male            Cogdill, Josh  SR-4
# 20        21       2017       D1   Dec  Male        Golubovic, Daniel  SR-4
# 21        22       2017       D1   Dec  Male          Walker, Jackson  SR-4
# 22        23       2017       D1   Dec  Male               Lint, Jack  SO-2
# 23        24       2017       D1   Dec  Male       Dougherty, William  JR-3
# 24        25       2017       D1   Dec  Male            Smith, Sawyer  JR-3
# 25        26       2017       D1   Dec  Male           Nielsen, Kevin  JR-3
# 26        27       2017       D1   Dec  Male           Rohner, Robert  SR-4
# 27        28       2017       D1   Dec  Male         Horn, Kristopher  SR-4
# 28        29       2017       D1   Dec  Male           Brendel, Tyler  SO-2
# 29        30       2017       D1   Dec  Male              Bloom, Alex  JR-3
# ..       ...        ...      ...   ...   ...                      ...   ...
# 70        71       2017       D1   Dec  Male              Davis, Zach  SR-4
# 71        72       2017       D1   Dec  Male             Majid, Kamar  SO-2
# 72        73       2017       D1   Dec  Male            Huber, Andrew  SO-2
# 73        73       2017       D1   Dec  Male             Fofana, Nick  JR-3
# 74        75       2017       D1   Dec  Male     Morales, Christopher  SR-4
# 75        76       2017       D1   Dec  Male          Robinson, Donte  SO-2
# 76        77       2017       D1   Dec  Male        Ballengee, Markus  FR-1
# 77        78       2017       D1   Dec  Male            Rivers, Grant  JR-3
# 78        79       2017       D1   Dec  Male             Looser, Ryan  JR-3
# 79        80       2017       D1   Dec  Male              Hicks, Cole  JR-3
# 80        81       2017       D1   Dec  Male           Griffin, Kaden  SO-2
# 81        82       2017       D1   Dec  Male           Powell, Hunter  JR-3
# 82        83       2017       D1   Dec  Male            Enerson, Ryan  SO-2
# 83        84       2017       D1   Dec  Male             Clancy, Kyle  SO-2
# 84        85       2017       D1   Dec  Male         Russi, Sebastian  SO-2
# 85        86       2017       D1   Dec  Male       Muldoon, Mackenzie  SO-2
# 86        87       2017       D1   Dec  Male   Romero Gonzales, Pablo  FR-1
# 87        88       2017       D1   Dec  Male          Hampton, Hayden  FR-1
# 88        89       2017       D1   Dec  Male            Lafaye, Reece  JR-3
# 89        90       2017       D1   Dec  Male             Beyer, Franz  JR-3
# 90        91       2017       D1   Dec  Male            Acevedo, Alec  SR-4
# 91        92       2017       D1   Dec  Male        Cudequest, Taylor  SR-4
# 92        93       2017       D1   Dec  Male         Torrance, Colton  JR-3
# 93        94       2017       D1   Dec  Male         Berstler, Calvin  JR-3
# 94        95       2017       D1   Dec  Male           Shattuck, Dion  JR-3
# 95        96       2017       D1   Dec  Male            Henshaw, Liam  SO-2
# 96        97       2017       D1   Dec  Male  Thurber-Blaser, Brendan  FR-1
# 97        98       2017       D1   Dec  Male           Rickman, Jacob  JR-3
# 98        98       2017       D1   Dec  Male          Kasupski, Caleb  FR-1
# 99       100       2017       D1   Dec  Male            Rhoads, Wyatt  SO-2
#
#                   TEAM  TIME  TIME_SECS  MARK  CONV  POINTS  \
# 0            Texas A&M   NaN        NaN   NaN   NaN    8539
# 1              Georgia   NaN        NaN   NaN   NaN    8345
# 2            Minnesota   NaN        NaN   NaN   NaN    8201
# 3             Kentucky   NaN        NaN   NaN   NaN    7973
# 4              Georgia   NaN        NaN   NaN   NaN    7948
# 5             Nebraska   NaN        NaN   NaN   NaN    7937
# 6                 Rice   NaN        NaN   NaN   NaN    7915
# 7                Texas   NaN        NaN   NaN   NaN    7897
# 8         Colorado St.   NaN        NaN   NaN   NaN    7801
# 9       South Carolina   NaN        NaN   NaN   NaN    7720
# 10               Texas   NaN        NaN   NaN   NaN    7715
# 11            Michigan   NaN        NaN   NaN   NaN    7713
# 12          Kent State   NaN        NaN   NaN   NaN    7640
# 13            Arkansas   NaN        NaN   NaN   NaN    7635
# 14       Wichita State   NaN        NaN   NaN   NaN    7610
# 15              Oregon   NaN        NaN   NaN   NaN    7566
# 16            Arkansas   NaN        NaN   NaN   NaN    7564
# 17              Oregon   NaN        NaN   NaN   NaN    7530
# 18      Michigan State   NaN        NaN   NaN   NaN    7529
# 19        Colorado St.   NaN        NaN   NaN   NaN    7508
# 20                Duke   NaN        NaN   NaN   NaN    7500
# 21                 BYU   NaN        NaN   NaN   NaN    7483
# 22            Virginia   NaN        NaN   NaN   NaN    7478
# 23                Iowa   NaN        NaN   NaN   NaN    7471
# 24           Wisconsin   NaN        NaN   NaN   NaN    7450
# 25                 BYU   NaN        NaN   NaN   NaN    7439
# 26                Duke   NaN        NaN   NaN   NaN    7423
# 27       UMass Amherst   NaN        NaN   NaN   NaN    7417
# 28          California   NaN        NaN   NaN   NaN    7413
# 29          Cincinnati   NaN        NaN   NaN   NaN    7401
# ..                 ...   ...        ...   ...   ...     ...
# 70             Liberty   NaN        NaN   NaN   NaN    6898
# 71               Akron   NaN        NaN   NaN   NaN    6890
# 72             Indiana   NaN        NaN   NaN   NaN    6870
# 73        Northeastern   NaN        NaN   NaN   NaN    6870
# 74             Houston   NaN        NaN   NaN   NaN    6857
# 75      Portland State   NaN        NaN   NaN   NaN    6852
# 76             Liberty   NaN        NaN   NaN   NaN    6840
# 77  North Carolina St.   NaN        NaN   NaN   NaN    6832
# 78          Kent State   NaN        NaN   NaN   NaN    6829
# 79      Long Beach St.   NaN        NaN   NaN   NaN    6826
# 80       Wichita State   NaN        NaN   NaN   NaN    6816
# 81              Baylor   NaN        NaN   NaN   NaN    6804
# 82  North Dakota State   NaN        NaN   NaN   NaN    6798
# 83            UC Davis   NaN        NaN   NaN   NaN    6787
# 84             Houston   NaN        NaN   NaN   NaN    6770
# 85       Virginia Tech   NaN        NaN   NaN   NaN    6758
# 86          High Point   NaN        NaN   NaN   NaN    6756
# 87      Arkansas State   NaN        NaN   NaN   NaN    6745
# 88         Weber State   NaN        NaN   NaN   NaN    6741
# 89        UL-Lafayette   NaN        NaN   NaN   NaN    6735
# 90      Sacramento St.   NaN        NaN   NaN   NaN    6734
# 91  Cal St. Northridge   NaN        NaN   NaN   NaN    6733
# 92                Rice   NaN        NaN   NaN   NaN    6714
# 93           Air Force   NaN        NaN   NaN   NaN    6709
# 94             Arizona   NaN        NaN   NaN   NaN    6699
# 95       Arizona State   NaN        NaN   NaN   NaN    6675
# 96             Montana   NaN        NaN   NaN   NaN    6660
# 97            Cal Poly   NaN        NaN   NaN   NaN    6655
# 98         Connecticut   NaN        NaN   NaN   NaN    6655
# 99          Iowa State   NaN        NaN   NaN   NaN    6638
#
#                                                  MEET     MEET DATE
# 0             SEC Outdoor Track & Field Championships  May 11, 2017
# 1                             Spec Towns Invitational   Apr 7, 2017
# 2         Mt. SAC Relays/CA Invitational Multi Events  Apr 12, 2017
# 3                             Spec Towns Invitational   Apr 7, 2017
# 4             SEC Outdoor Track & Field Championships  May 11, 2017
# 5                             Spec Towns Invitational   Apr 7, 2017
# 6            2017 90th Clyde Littlefield Texas Relays  Mar 29, 2017
# 7            2017 90th Clyde Littlefield Texas Relays  Mar 29, 2017
# 8         Mt. SAC Relays/CA Invitational Multi Events  Apr 12, 2017
# 9             SEC Outdoor Track & Field Championships  May 11, 2017
# 10         Big 12 Outdoor Track & Field Championships  May 12, 2017
# 11                      Big Ten Outdoor Championships  May 12, 2017
# 12   Mid-American Outdoor Track & Field Championships  May 11, 2017
# 13            SEC Outdoor Track & Field Championships  May 11, 2017
# 14             Sam Adams Combined Events Invitational   Apr 7, 2017
# 15        Mt. SAC Relays/CA Invitational Multi Events  Apr 12, 2017
# 16                        John McDonnell Invitational  Apr 21, 2017
# 17          2017 Pac-12 Combined Events Championships   May 6, 2017
# 18                                 Virginia Challenge  Apr 21, 2017
# 19  Mountain West Outdoor Track & Field Championships  May 10, 2017
# 20        Mt. SAC Relays/CA Invitational Multi Events  Apr 12, 2017
# 21                       2017 BYU Cougar Invitational  May 12, 2017
# 22                                 Virginia Challenge  Apr 21, 2017
# 23        Mt. SAC Relays/CA Invitational Multi Events  Apr 12, 2017
# 24                        John McDonnell Invitational  Apr 21, 2017
# 25           2017 90th Clyde Littlefield Texas Relays  Mar 29, 2017
# 26        Mt. SAC Relays/CA Invitational Multi Events  Apr 12, 2017
# 27        NEICAAA Outdoor Track & Field Championships  May 12, 2017
# 28          2017 Pac-12 Combined Events Championships   May 6, 2017
# 29   The American Outdoor Track & Field Championships  May 12, 2017
# ..                                                ...           ...
# 70                                 Virginia Challenge  Apr 21, 2017
# 71   Mid-American Outdoor Track & Field Championships  May 11, 2017
# 72                                   Tennessee Relays   Apr 6, 2017
# 73                Miami Hurricane Alumni Invitational   Apr 7, 2017
# 74   The American Outdoor Track & Field Championships  May 12, 2017
# 75   2017 Big Sky Outdoor Track & Field Championships  May 10, 2017
# 76                                 Virginia Challenge  Apr 21, 2017
# 77            ACC Outdoor Track & Field Championships  May 12, 2017
# 78   Mid-American Outdoor Track & Field Championships  May 11, 2017
# 79                  UC Riverside Spring Track Classic  Mar 23, 2017
# 80      Wichita State KT Woodman Heptathlon/Decathlon  Apr 11, 2017
# 81         Big 12 Outdoor Track & Field Championships  May 12, 2017
# 82  The Summit League Outdoor Track & Field Champi...  May 11, 2017
# 83                  2017 Big West Multi Championships   May 5, 2017
# 84   The American Outdoor Track & Field Championships  May 12, 2017
# 85            ACC Outdoor Track & Field Championships  May 12, 2017
# 86      Big South Outdoor Track & Field Championships  May 10, 2017
# 87     Sun Belt Outdoor Track and Field Championships  May 12, 2017
# 88   2017 Big Sky Outdoor Track & Field Championships  May 10, 2017
# 89     Sun Belt Outdoor Track and Field Championships  May 12, 2017
# 90   2017 Big Sky Outdoor Track & Field Championships  May 10, 2017
# 91                  2017 Big West Multi Championships   May 5, 2017
# 92                      Shirley Crowe Combined Events  Mar 14, 2017
# 93  Mountain West Outdoor Track & Field Championships  May 10, 2017
# 94                                 Jim Click Shootout   Apr 8, 2017
# 95                                 Jim Click Shootout   Apr 8, 2017
# 96                                       Montana Open  Apr 27, 2017
# 97                  2017 Big West Multi Championships   May 5, 2017
# 98   The American Outdoor Track & Field Championships  May 12, 2017
# 99         Big 12 Outdoor Track & Field Championships  May 12, 2017
#
# [100 rows x 15 columns]

# %%
dfs_copy[13].head()
# Out:
#    Unnamed: 0             ATHLETE  YEAR           TEAM      TIME  \
# 0           1        Rohrer, Anna  FR-1     Notre Dame  31:58.99
# 1           2   Taylor, Charlotte  SR-4  San Francisco  32:11.80
# 2           3       Wright, Alice  JR-3     New Mexico  32:29.28
# 3           4      Kempfer, Jamie  SO-2       Missouri  33:09.67
# 4           5  Blaney, Anne-Marie  SR-4            UCF  33:18.81
#
#                          MEET     MEET DATE
# 0       Stanford Invitational  Mar 31, 2017
# 1       Stanford Invitational  Mar 31, 2017
# 2  Payton Jordan Invitational   May 5, 2017
# 3       Stanford Invitational  Mar 31, 2017
# 4   Stanford Cardinal Classic  Apr 21, 2017

# %%
# add event, sex champ_year and division column to each dataframe in list of dataframes, add column for time converted to seconds

def add_variables(df_list, division):
    '''Take in list of dataframes, division(str), champ_year(str).  
       Loop through list of data frames and add column for:
       event, sex, division and championship year'''
    
    # event list (alternating sexes for each event)
    events = ['100', '100', '200', '200', '400', '400', '800', '800', '1500', '1500', '5000', '5000', '10000', '10000', 
              '100H', '110H', '400H', '400H', '3000S', '3000S', '4x100', '4x100', '4x400', '4x400', 
              'HJ', 'HJ', 'PV', 'PV', 'LJ', 'LJ', 'TJ', 'TJ', 'SP', 'SP', 'DT', 'DT', 'HT', 'HT', 'JT', 'JT', 
              'Hep', 'Dec']
    
    
    for i in range(len(df_list)):
        df_list[i]['EVENT'] = events[i]
        
    # male recorded first in df for each event except last two dfs (hep and dec are reversed for some reason)
    for i in range(len(df_list)-3):
        if i%2 == 0:
            df_list[i]['SEX'] = 'Male'
        else:
            df_list[i]['SEX'] = 'Female'
    df_list[40]['SEX'] = 'Female'
    df_list[41]['SEX'] = 'Male'
            
    for i in range(len(df_list)):
        df_list[i]['DIVISION'] = division
        
    for i in range(len(df_list)):
        df_list[i]['CHAMP_YEAR'] = [j[-4:] for j in dfs_copy[40]['MEET DATE']]
        
    # rename column to POSITION
    for i in range(len(df_list)):
        df_list[i].rename(columns={'Unnamed: 0' : 'POSITION'}, inplace=True)
        
    #CONVERT TIME TO TOTAL SECONDS            
    
    # reorder and drop columns
    col_names = ['POSITION', 'CHAMP_YEAR', 'DIVISION', 'EVENT', 'SEX', 'ATHLETE', 'YEAR', 'TEAM', 'TIME', 'TIME_SECS', 
                 'MARK', 'CONV', 'POINTS', 'MEET', 'MEET DATE']
    for i in range(len(df_list)):
        df_list[i] = df_list[i].reindex(columns=col_names)

# %%
add_variables(dfs_copy, 'D1')

# %%
dfs_copy[12]
# Out:
#     POSITION CHAMP_YEAR DIVISION  EVENT   SEX              ATHLETE  YEAR  \
# 0          1       2017       D1  10000  Male     Chelanga, Alfred  JR-3
# 1          2       2017       D1  10000  Male          Scott, Marc  SR-4
# 2          3       2017       D1  10000  Male       Peterson, Erik  SR-4
# 3          4       2017       D1  10000  Male        Mock, Jerrell  JR-3
# 4          5       2017       D1  10000  Male     Kosgei, Antibahs  SR-4
# 5          6       2017       D1  10000  Male      Kibichiy, Edwin  SR-4
# 6          7       2017       D1  10000  Male         Choge, Jacob  FR-1
# 7          8       2017       D1  10000  Male      Parsons, George  SR-4
# 8          9       2017       D1  10000  Male       Herriott, Zach  SR-4
# 9         10       2017       D1  10000  Male       Young, Clayton  SO-2
# 10        11       2017       D1  10000  Male       Fischer, Grant  JR-3
# 11        12       2017       D1  10000  Male     Cheserek, Edward  SR-4
# 12        13       2017       D1  10000  Male          Short, Alex  SR-4
# 13        14       2017       D1  10000  Male       Thomson, Jacob  JR-3
# 14        15       2017       D1  10000  Male        Fischer, Reed  SR-4
# 15        16       2017       D1  10000  Male      Baxter, Matthew  SR-4
# 16        17       2017       D1  10000  Male       Brandt, Robert  FR-1
# 17        18       2017       D1  10000  Male    Guillorel, Arsène  JR-3
# 18        19       2017       D1  10000  Male          Ruiz, Clark  JR-3
# 19        20       2017       D1  10000  Male         Abdi, Hassan  JR-3
# 20        21       2017       D1  10000  Male       Kirui, Gilbert  SO-2
# 21        22       2017       D1  10000  Male        Reichow, Joel  SR-4
# 22        23       2017       D1  10000  Male         Kemboi, Amon  FR-1
# 23        24       2017       D1  10000  Male          Terer, Amon  SR-4
# 24        25       2017       D1  10000  Male     Linkletter, Rory  SO-2
# 25        26       2017       D1  10000  Male  Lautenslager, Craig  SR-4
# 26        27       2017       D1  10000  Male     Barus, Sylvester  JR-3
# 27        28       2017       D1  10000  Male        Schutte, Noah  SO-2
# 28        29       2017       D1  10000  Male     Harper, Jonathan  SR-4
# 29        30       2017       D1  10000  Male        Kirwa, Azaria  SO-2
# ..       ...        ...      ...    ...   ...                  ...   ...
# 70        71       2017       D1  10000  Male      Pollard, Thomas  FR-1
# 71        72       2017       D1  10000  Male        Forsyth, Ryan  JR-3
# 72        73       2017       D1  10000  Male          Lara, Frank  JR-3
# 73        74       2017       D1  10000  Male      Gonzales, Ethan  SO-2
# 74        75       2017       D1  10000  Male       Gallagher, Wes  SR-4
# 75        76       2017       D1  10000  Male        Jones, Nathan  JR-3
# 76        77       2017       D1  10000  Male       Neuman, Travis  JR-3
# 77        78       2017       D1  10000  Male          Roush, Ryan  SR-4
# 78        79       2017       D1  10000  Male         Meyer, Keith  SR-4
# 79        80       2017       D1  10000  Male        Hoffert, Jake  FR-1
# 80        81       2017       D1  10000  Male        Wells, Austin  SR-4
# 81        82       2017       D1  10000  Male      Sweatt, Garrett  SR-4
# 82        83       2017       D1  10000  Male      Shearn, Brendan  SR-4
# 83        84       2017       D1  10000  Male      Kiprono, Reuben  SO-2
# 84        85       2017       D1  10000  Male          Burke, Sean  FR-1
# 85        86       2017       D1  10000  Male       Stroede, Bryce  JR-3
# 86        87       2017       D1  10000  Male     Crozier, Michael  JR-3
# 87        88       2017       D1  10000  Male       Pengelly, Sean  SR-4
# 88        89       2017       D1  10000  Male     McGowan, Timothy  JR-3
# 89        90       2017       D1  10000  Male         Lynch, Jason  SR-4
# 90        91       2017       D1  10000  Male       England, Bryce  JR-3
# 91        92       2017       D1  10000  Male       McGuire, Wyatt  SO-2
# 92        93       2017       D1  10000  Male          Diaz, Jonah  SR-4
# 93        94       2017       D1  10000  Male       Gonzalez, Juan  JR-3
# 94        95       2017       D1  10000  Male     Fernandez, Bryan  JR-3
# 95        96       2017       D1  10000  Male          White, Drew  SR-4
# 96        97       2017       D1  10000  Male        Pearce, Henry  SR-4
# 97        98       2017       D1  10000  Male      Polerecky, Jack  JR-3
# 98        99       2017       D1  10000  Male        Capra, Trevor  JR-3
# 99       100       2017       D1  10000  Male    Martin, Christian  JR-3
#
#                    TEAM      TIME  TIME_SECS  MARK  CONV  POINTS  \
# 0               Alabama  28:04.95        NaN   NaN   NaN     NaN
# 1                 Tulsa  28:07.97        NaN   NaN   NaN     NaN
# 2                Butler  28:11.02        NaN   NaN   NaN     NaN
# 3          Colorado St.  28:11.80        NaN   NaN   NaN     NaN
# 4               Alabama  28:35.79        NaN   NaN   NaN     NaN
# 5            Louisville  28:38.06        NaN   NaN   NaN     NaN
# 6      Mid. Tenn. State  28:42.31        NaN   NaN   NaN     NaN
# 7    North Carolina St.  28:43.74        NaN   NaN   NaN     NaN
# 8              Virginia  28:44.22        NaN   NaN   NaN     NaN
# 9                   BYU  28:45.36        NaN   NaN   NaN     NaN
# 10         Colorado St.  28:45.83        NaN   NaN   NaN     NaN
# 11               Oregon  28:46.48        NaN   NaN   NaN     NaN
# 12        San Francisco  28:46.83        NaN   NaN   NaN     NaN
# 13             Kentucky  28:47.55        NaN   NaN   NaN     NaN
# 14                Drake  28:47.86        NaN   NaN   NaN     NaN
# 15     Northern Arizona  28:48.02        NaN   NaN   NaN     NaN
# 16           California  28:48.38        NaN   NaN   NaN     NaN
# 17              Samford  28:51.75        NaN   NaN   NaN     NaN
# 18       Michigan State  28:52.46        NaN   NaN   NaN     NaN
# 19       Oklahoma State  28:54.86        NaN   NaN   NaN     NaN
# 20                 Iona  28:54.90        NaN   NaN   NaN     NaN
# 21     South Dakota St.  28:56.24        NaN   NaN   NaN     NaN
# 22             Campbell  28:57.45        NaN   NaN   NaN     NaN
# 23             Campbell  28:57.72        NaN   NaN   NaN     NaN
# 24                  BYU  28:58.74        NaN   NaN   NaN     NaN
# 25         UT-Arlington  29:00.59        NaN   NaN   NaN     NaN
# 26       Oklahoma State  29:04.65        NaN   NaN   NaN     NaN
# 27             Portland  29:05.17        NaN   NaN   NaN     NaN
# 28                  BYU  29:05.50        NaN   NaN   NaN     NaN
# 29              Liberty  29:05.57        NaN   NaN   NaN     NaN
# ..                  ...       ...        ...   ...   ...     ...
# 70           Iowa State  29:30.77        NaN   NaN   NaN     NaN
# 71             Colorado  29:32.38        NaN   NaN   NaN     NaN
# 72               Furman  29:32.54        NaN   NaN   NaN     NaN
# 73             Colorado  29:33.47        NaN   NaN   NaN     NaN
# 74             Ole Miss  29:33.81        NaN   NaN   NaN     NaN
# 75        McNeese State  29:33.82        NaN   NaN   NaN     NaN
# 76               Oregon  29:33.95        NaN   NaN   NaN     NaN
# 77       Youngstown St.  29:34.12        NaN   NaN   NaN     NaN
# 78     SIU Edwardsville  29:34.93        NaN   NaN   NaN     NaN
# 79              Bradley  29:35.06        NaN   NaN   NaN     NaN
# 80            Texas A&M  29:35.93        NaN   NaN   NaN     NaN
# 81             Stanford  29:36.26        NaN   NaN   NaN     NaN
# 82                 Penn  29:36.46        NaN   NaN   NaN     NaN
# 83             Portland  29:36.62        NaN   NaN   NaN     NaN
# 84       Boston College  29:37.01        NaN   NaN   NaN     NaN
# 85              Oakland  29:37.19        NaN   NaN   NaN     NaN
# 86           Georgetown  29:38.48        NaN   NaN   NaN     NaN
# 87             Illinois  29:38.62        NaN   NaN   NaN     NaN
# 88           Penn State  29:38.64        NaN   NaN   NaN     NaN
# 89          Utah Valley  29:38.75        NaN   NaN   NaN     NaN
# 90  Saint Francis (Pa.)  29:38.84        NaN   NaN   NaN     NaN
# 91             Nebraska  29:39.14        NaN   NaN   NaN     NaN
# 92                 UCLA  29:39.73        NaN   NaN   NaN     NaN
# 93             Lipscomb  29:39.92        NaN   NaN   NaN     NaN
# 94               Oregon  29:39.95        NaN   NaN   NaN     NaN
# 95             Missouri  29:41.10        NaN   NaN   NaN     NaN
# 96                Tulsa  29:41.12        NaN   NaN   NaN     NaN
# 97     Loyola Marymount  29:43.22        NaN   NaN   NaN     NaN
# 98     South Dakota St.  29:43.23        NaN   NaN   NaN     NaN
# 99             Colorado  29:43.43        NaN   NaN   NaN     NaN
#
#                                           MEET     MEET DATE
# 0                        Stanford Invitational  Mar 31, 2017
# 1                   Payton Jordan Invitational   May 5, 2017
# 2                        Stanford Invitational  Mar 31, 2017
# 3                        Stanford Invitational  Mar 31, 2017
# 4                        Stanford Invitational  Mar 31, 2017
# 5                               Raleigh Relays  Mar 24, 2017
# 6                               Mt. SAC Relays  Apr 13, 2017
# 7                        Stanford Invitational  Mar 31, 2017
# 8                               Raleigh Relays  Mar 24, 2017
# 9                        Stanford Invitational  Mar 31, 2017
# 10                       Stanford Invitational  Mar 31, 2017
# 11                       Stanford Invitational  Mar 31, 2017
# 12                       Stanford Invitational  Mar 31, 2017
# 13                              Raleigh Relays  Mar 24, 2017
# 14                       Stanford Invitational  Mar 31, 2017
# 15                       Stanford Invitational  Mar 31, 2017
# 16                       Stanford Invitational  Mar 31, 2017
# 17                       Stanford Invitational  Mar 31, 2017
# 18                              Raleigh Relays  Mar 24, 2017
# 19                       Stanford Invitational  Mar 31, 2017
# 20                       Stanford Invitational  Mar 31, 2017
# 21                       Stanford Invitational  Mar 31, 2017
# 22                              Raleigh Relays  Mar 24, 2017
# 23                              Mt. SAC Relays  Apr 13, 2017
# 24                              Mt. SAC Relays  Apr 13, 2017
# 25                       Stanford Invitational  Mar 31, 2017
# 26                       Stanford Invitational  Mar 31, 2017
# 27                       Stanford Invitational  Mar 31, 2017
# 28                       Stanford Invitational  Mar 31, 2017
# 29                              Raleigh Relays  Mar 24, 2017
# ..                                         ...           ...
# 70  Big 12 Outdoor Track & Field Championships  May 12, 2017
# 71                        Pac-12 Championships  May 13, 2017
# 72                              Raleigh Relays  Mar 24, 2017
# 73                        Pac-12 Championships  May 13, 2017
# 74                       Stanford Invitational  Mar 31, 2017
# 75       San Francisco State Distance Carnival  Mar 31, 2017
# 76                       Stanford Invitational  Mar 31, 2017
# 77                       Bison Outdoor Classic  Apr 14, 2017
# 78                              Raleigh Relays  Mar 24, 2017
# 79                              Mt. SAC Relays  Apr 13, 2017
# 80                              Mt. SAC Relays  Apr 13, 2017
# 81                        Pac-12 Championships  May 13, 2017
# 82                       Stanford Invitational  Mar 31, 2017
# 83                              Mt. SAC Relays  Apr 13, 2017
# 84                       Stanford Invitational  Mar 31, 2017
# 85                              Raleigh Relays  Mar 24, 2017
# 86                                 Penn Relays  Apr 27, 2017
# 87                              Mt. SAC Relays  Apr 13, 2017
# 88               Big Ten Outdoor Championships  May 12, 2017
# 89                              Mt. SAC Relays  Apr 13, 2017
# 90                       Bison Outdoor Classic  Apr 14, 2017
# 91               Big Ten Outdoor Championships  May 12, 2017
# 92                        Pac-12 Championships  May 13, 2017
# 93                              Raleigh Relays  Mar 24, 2017
# 94                           Portland Twilight  May 12, 2017
# 95       2017 Drake Relays presented by Hy-Vee  Apr 26, 2017
# 96                              Mt. SAC Relays  Apr 13, 2017
# 97                           Portland Twilight  May 12, 2017
# 98       2017 Drake Relays presented by Hy-Vee  Apr 26, 2017
# 99                   Stanford Cardinal Classic  Apr 21, 2017
#
# [100 rows x 15 columns]

# %% [markdown]
# ### List of URLS for each Division I and Division II

# %%
# list of urls for available years in each division
D1_top100 = ['https://www.tfrrs.org/archived_lists/2568/2019_NCAA_Division_I_Outdoor_Qualifying_(FINAL)/2019/o',
 'https://www.tfrrs.org/archived_lists/2279/2018_NCAA_Division_I_Outdoor_Qualifying_(FINAL)/2018/o',
 'https://www.tfrrs.org/archived_lists/1912/2017_NCAA_Div._I_Outdoor_Qualifying_(FINAL)/2017/o',
 'https://www.tfrrs.org/archived_lists/1688/2016_NCAA_Division_I_Outdoor_Qualifying_(FINAL)/2016/o',
 'https://www.tfrrs.org/archived_lists/1439/2015_NCAA_Division_I_Outdoor_Qualifying_(FINAL)/2015/o',
 'https://www.tfrrs.org/archived_lists/1228/2014_NCAA_Division_I_Outdoor_Qualifying_(FINAL)/2014/o',
 'https://www.tfrrs.org/archived_lists/1029/2013_NCAA_Division_I_Outdoor_Qualifying_(FINAL)/2013/o',
 'https://www.tfrrs.org/archived_lists/840/2012_NCAA_Div._I_Outdoor_Qualifiers_(Final)/2012/o',
 'https://www.tfrrs.org/archived_lists/673/2011_NCAA_Division_I_Outdoor_POP_List_(FINAL)/2011/o',
 'https://www.tfrrs.org/archived_lists/528/2010_NCAA_Division_I_Outdoor_POP_List_(FINAL)/2010/o']

D2_top100 = ['https://www.tfrrs.org/archived_lists/2571/2019_NCAA_Div._II_Outdoor_Qualifying_(FINAL)/2019/o',
 'https://www.tfrrs.org/lists/2282.html',
 'https://www.tfrrs.org/lists/1913.html',
 'https://www.tfrrs.org/lists/1685.html',
 'https://www.tfrrs.org/lists/1442.html',
 'https://www.tfrrs.org/lists/1231.html',
 'https://www.tfrrs.org/lists/1032.html',
 'https://www.tfrrs.org/lists/841.html',
 'https://www.tfrrs.org/lists/674.html',
 'https://www.tfrrs.org/lists/529.html']

# %%
# %%time
d1_scraped = scrape_tfrrs(D1_top100, 'D1')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-33-3a7a0920a22a> in scrape_tfrrs(url_list, division)
#      10
#      11         # clean each df in df_list
# ---> 12         clean_dfs(df_list, 'D1')
#      13
#      14         # add each cleaned df to cleaned_dfs list
#
# <ipython-input-32-bc99d77f8cb5> in clean_dfs(df_list, division)
#       7        '''
#       8
# ----> 9     add_events(df_list)
#      10     add_sex(df_list)
#      11     add_division(df_list, division)
#
# <ipython-input-3-5ba7481899b1> in add_events(df_list)
#       6               'Dec', 'Hep']
#       7     for i in range(len(df_list)):
# ----> 8         df_list[i]['EVENT'] = events[i]
#
# IndexError: list index out of range

# %%
# %%time
d2_scraped = scrape_tfrrs(D2_top100, 'D2')
# Out:
# Wall time: 14min 57s

# %%
d1_scraped.CHAMP_YEAR.unique()
# Out:
# array(['2019', '2018'], dtype=object)

# %%
# # write to csv
# d1_scraped.to_csv('d1_scraped.csv')

# %%
# write to csv
d2_scraped.to_csv('d2_scraped.csv')

# %%
# graph some stuff
import matplotlib.pyplot as plt
from matplotlib import dates
